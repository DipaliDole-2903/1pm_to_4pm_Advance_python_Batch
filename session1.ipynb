# %% [markdown]
# # session_1 - Basic to Advance

# %% [markdown]
# - subheading1
# - subheading2

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('Hello world again')
# Out:
# Hello world again

# %%
print("ETLHIVE")
# Out:
# ETLHIVE

# %%
LST=[1,23,4,5,6]

# %%
LST
# Out:
# [1, 23, 4, 5, 6]
