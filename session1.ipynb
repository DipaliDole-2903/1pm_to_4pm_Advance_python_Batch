# %% [markdown]
# # session_1

# %% [markdown]
# # session_1

# %% [markdown]
# - subheading1
# - subheading2

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('Hello world again')
# Out:
# Hello world again

# %%
print('Hello world again')
# Out:
# Hello world again
